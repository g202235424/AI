# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Cold min/Downloads/mushrooms.csv")
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
data.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in data.columns:
    data[i]=le.fit_transform(data[i])

# %%
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
df=data.drop('class',axis=1)
df.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# 1                         2                       7                       7
# 2                         2                       7                       7
# 3                         2                       7                       7
# 4                         2                       7                       7
#
#    veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0          0           2            1          4                  2
# 1          0           2            1          4                  3
# 2          0           2            1          4                  3
# 3          0           2            1          4                  2
# 4          0           2            1          0                  3
#
#    population  habitat
# 0           3        5
# 1           2        1
# 2           2        3
# 3           3        5
# 4           0        1
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
y

# %%
#Splitting the data into training and test test
X = data.iloc[:,1:23].values
y = data.iloc[:,0].values

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
y1 = encoder.fit_transform(y)

Y = pd.get_dummies(y1).values


from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
Y
# Out:
# array([[0, 1],
#        [1, 0],
#        [1, 0],
#        ...,
#        [1, 0],
#        [0, 1],
#        [1, 0]], dtype=uint8)

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(22,),activation='tanh'))
model.add(Dense(8,activation='softmax'))
model.add(Dense(6,activation='softmax'))
model.add(Dense(2,activation='softmax'))

model.compile(Adam(lr=0.04),'binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_132 (Dense)           (None, 10)                230
#
#  dense_133 (Dense)           (None, 8)                 88
#
#  dense_134 (Dense)           (None, 6)                 54
#
#  dense_135 (Dense)           (None, 2)                 14
#
# =================================================================
# Total params: 386
# Trainable params: 386
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fitting the model and predicting 

# fit network
model_history=model.fit(x=X_train, y=y_train, epochs=100, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/100
# 204/204 [==============================] - 3s 7ms/step - loss: 0.3762 - accuracy: 0.8621 - val_loss: 0.2491 - val_accuracy: 0.9212
# Epoch 2/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2843 - accuracy: 0.9081 - val_loss: 0.2210 - val_accuracy: 0.9311
# Epoch 3/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2546 - accuracy: 0.9189 - val_loss: 0.1926 - val_accuracy: 0.9446
# Epoch 4/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.3338 - accuracy: 0.8694 - val_loss: 0.5082 - val_accuracy: 0.7323
# Epoch 5/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.4318 - accuracy: 0.7864 - val_loss: 0.2686 - val_accuracy: 0.9132
# Epoch 6/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2494 - accuracy: 0.9186 - val_loss: 0.1994 - val_accuracy: 0.9446
# Epoch 7/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2746 - accuracy: 0.9091 - val_loss: 0.2655 - val_accuracy: 0.9329
# Epoch 8/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2495 - accuracy: 0.9251 - val_loss: 0.2190 - val_accuracy: 0.9335
# Epoch 9/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2763 - accuracy: 0.9148 - val_loss: 0.2062 - val_accuracy: 0.9440
# Epoch 10/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2083 - accuracy: 0.9380 - val_loss: 0.1897 - val_accuracy: 0.9483
# Epoch 11/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2793 - accuracy: 0.9023 - val_loss: 0.2371 - val_accuracy: 0.9225
# Epoch 12/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2609 - accuracy: 0.9232 - val_loss: 0.2057 - val_accuracy: 0.9446
# Epoch 13/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2607 - accuracy: 0.9120 - val_loss: 0.3656 - val_accuracy: 0.8738
# Epoch 14/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2599 - accuracy: 0.9169 - val_loss: 0.3360 - val_accuracy: 0.8720
# Epoch 15/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2626 - accuracy: 0.9208 - val_loss: 0.3331 - val_accuracy: 0.8726
# Epoch 16/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2394 - accuracy: 0.9215 - val_loss: 0.1926 - val_accuracy: 0.9477
# Epoch 17/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2208 - accuracy: 0.9365 - val_loss: 0.1999 - val_accuracy: 0.9446
# Epoch 18/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2151 - accuracy: 0.9377 - val_loss: 0.1999 - val_accuracy: 0.9440
# Epoch 19/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2288 - accuracy: 0.9303 - val_loss: 0.4541 - val_accuracy: 0.8338
# Epoch 20/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.3429 - accuracy: 0.8789 - val_loss: 0.1860 - val_accuracy: 0.9514
# Epoch 21/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2513 - accuracy: 0.9183 - val_loss: 0.2382 - val_accuracy: 0.9212
# Epoch 22/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2109 - accuracy: 0.9386 - val_loss: 0.1926 - val_accuracy: 0.9495
# Epoch 23/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1979 - accuracy: 0.9432 - val_loss: 0.1950 - val_accuracy: 0.9495
# Epoch 24/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1975 - accuracy: 0.9432 - val_loss: 0.1964 - val_accuracy: 0.9495
# Epoch 25/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1975 - accuracy: 0.9432 - val_loss: 0.1931 - val_accuracy: 0.9495
# Epoch 26/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1973 - accuracy: 0.9432 - val_loss: 0.1934 - val_accuracy: 0.9495
# Epoch 27/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1974 - accuracy: 0.9432 - val_loss: 0.1928 - val_accuracy: 0.9495
# Epoch 28/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1974 - accuracy: 0.9432 - val_loss: 0.1971 - val_accuracy: 0.9495
# Epoch 29/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1967 - val_accuracy: 0.9495
# Epoch 30/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1973 - accuracy: 0.9432 - val_loss: 0.1960 - val_accuracy: 0.9495
# Epoch 31/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1945 - val_accuracy: 0.9495
# Epoch 32/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1981 - accuracy: 0.9432 - val_loss: 0.1948 - val_accuracy: 0.9495
# Epoch 33/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1955 - val_accuracy: 0.9495
# Epoch 34/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1972 - accuracy: 0.9432 - val_loss: 0.1988 - val_accuracy: 0.9495
# Epoch 35/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1935 - val_accuracy: 0.9495
# Epoch 36/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1980 - accuracy: 0.9432 - val_loss: 0.1940 - val_accuracy: 0.9495
# Epoch 37/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1980 - accuracy: 0.9432 - val_loss: 0.1946 - val_accuracy: 0.9495
# Epoch 38/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1979 - accuracy: 0.9432 - val_loss: 0.1986 - val_accuracy: 0.9495
# Epoch 39/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1977 - accuracy: 0.9432 - val_loss: 0.1936 - val_accuracy: 0.9495
# Epoch 40/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1978 - accuracy: 0.9432 - val_loss: 0.1937 - val_accuracy: 0.9495
# Epoch 41/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1980 - accuracy: 0.9432 - val_loss: 0.1950 - val_accuracy: 0.9495
# Epoch 42/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1967 - val_accuracy: 0.9495
# Epoch 43/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1975 - accuracy: 0.9432 - val_loss: 0.1955 - val_accuracy: 0.9495
# Epoch 44/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1955 - val_accuracy: 0.9495
# Epoch 45/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1969 - accuracy: 0.9432 - val_loss: 0.1937 - val_accuracy: 0.9495
# Epoch 46/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1982 - accuracy: 0.9432 - val_loss: 0.1945 - val_accuracy: 0.9495
# Epoch 47/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1982 - accuracy: 0.9432 - val_loss: 0.1928 - val_accuracy: 0.9495
# Epoch 48/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1980 - accuracy: 0.9432 - val_loss: 0.1943 - val_accuracy: 0.9495
# Epoch 49/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1928 - val_accuracy: 0.9495
# Epoch 50/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1950 - val_accuracy: 0.9495
# Epoch 51/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1983 - accuracy: 0.9432 - val_loss: 0.1937 - val_accuracy: 0.9495
# Epoch 52/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1980 - accuracy: 0.9432 - val_loss: 0.1928 - val_accuracy: 0.9495
# Epoch 53/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1979 - accuracy: 0.9432 - val_loss: 0.1979 - val_accuracy: 0.9495
# Epoch 54/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1978 - accuracy: 0.9432 - val_loss: 0.1937 - val_accuracy: 0.9495
# Epoch 55/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1973 - accuracy: 0.9432 - val_loss: 0.1943 - val_accuracy: 0.9495
# Epoch 56/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1979 - accuracy: 0.9432 - val_loss: 0.1973 - val_accuracy: 0.9495
# Epoch 57/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1981 - accuracy: 0.9432 - val_loss: 0.1929 - val_accuracy: 0.9495
# Epoch 58/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1974 - accuracy: 0.9432 - val_loss: 0.1941 - val_accuracy: 0.9495
# Epoch 59/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1989 - accuracy: 0.9432 - val_loss: 0.1938 - val_accuracy: 0.9495
# Epoch 60/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1978 - accuracy: 0.9432 - val_loss: 0.1937 - val_accuracy: 0.9495
# Epoch 61/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1977 - accuracy: 0.9432 - val_loss: 0.1961 - val_accuracy: 0.9495
# Epoch 62/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1960 - val_accuracy: 0.9495
# Epoch 63/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1976 - accuracy: 0.9432 - val_loss: 0.1958 - val_accuracy: 0.9495
# Epoch 64/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1974 - accuracy: 0.9432 - val_loss: 0.1949 - val_accuracy: 0.9495
# Epoch 65/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1977 - accuracy: 0.9432 - val_loss: 0.1992 - val_accuracy: 0.9495
# Epoch 66/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.3895 - accuracy: 0.8149 - val_loss: 0.5116 - val_accuracy: 0.7323
# Epoch 67/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5081 - accuracy: 0.7303 - val_loss: 0.5100 - val_accuracy: 0.7323
# Epoch 68/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5083 - accuracy: 0.7303 - val_loss: 0.5074 - val_accuracy: 0.7323
# Epoch 69/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5079 - accuracy: 0.7303 - val_loss: 0.5109 - val_accuracy: 0.7323
# Epoch 70/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5072 - accuracy: 0.7303 - val_loss: 0.5074 - val_accuracy: 0.7323
# Epoch 71/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5072 - accuracy: 0.7303 - val_loss: 0.5073 - val_accuracy: 0.7323
# Epoch 72/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5071 - accuracy: 0.7303 - val_loss: 0.5072 - val_accuracy: 0.7323
# Epoch 73/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5067 - accuracy: 0.7303 - val_loss: 0.5074 - val_accuracy: 0.7323
# Epoch 74/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5083 - accuracy: 0.7303 - val_loss: 0.5092 - val_accuracy: 0.7323
# Epoch 75/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5070 - accuracy: 0.7303 - val_loss: 0.5078 - val_accuracy: 0.7323
# Epoch 76/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5070 - accuracy: 0.7303 - val_loss: 0.5080 - val_accuracy: 0.7323
# Epoch 77/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5064 - accuracy: 0.7303 - val_loss: 0.5070 - val_accuracy: 0.7323
# Epoch 78/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5066 - accuracy: 0.7303 - val_loss: 0.5084 - val_accuracy: 0.7323
# Epoch 79/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5075 - accuracy: 0.7303 - val_loss: 0.5068 - val_accuracy: 0.7323
# Epoch 80/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5078 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 81/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5071 - accuracy: 0.7303 - val_loss: 0.5069 - val_accuracy: 0.7323
# Epoch 82/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5073 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 83/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5076 - accuracy: 0.7303 - val_loss: 0.5070 - val_accuracy: 0.7323
# Epoch 84/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5071 - accuracy: 0.7303 - val_loss: 0.5079 - val_accuracy: 0.7323
# Epoch 85/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5071 - accuracy: 0.7303 - val_loss: 0.5104 - val_accuracy: 0.7323
# Epoch 86/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5078 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 87/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5066 - accuracy: 0.7303 - val_loss: 0.5085 - val_accuracy: 0.7323
# Epoch 88/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5081 - accuracy: 0.7303 - val_loss: 0.5081 - val_accuracy: 0.7323
# Epoch 89/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5078 - accuracy: 0.7303 - val_loss: 0.5077 - val_accuracy: 0.7323
# Epoch 90/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5072 - accuracy: 0.7303 - val_loss: 0.5076 - val_accuracy: 0.7323
# Epoch 91/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5067 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 92/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5074 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 93/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5067 - accuracy: 0.7303 - val_loss: 0.5106 - val_accuracy: 0.7323
# Epoch 94/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5073 - accuracy: 0.7303 - val_loss: 0.5068 - val_accuracy: 0.7323
# Epoch 95/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5065 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 96/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5080 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 97/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5063 - accuracy: 0.7303 - val_loss: 0.5071 - val_accuracy: 0.7323
# Epoch 98/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5080 - accuracy: 0.7303 - val_loss: 0.5067 - val_accuracy: 0.7323
# Epoch 99/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5070 - accuracy: 0.7303 - val_loss: 0.5074 - val_accuracy: 0.7323
# Epoch 100/100
# 204/204 [==============================] - 1s 5ms/step - loss: 0.5071 - accuracy: 0.7303 - val_loss: 0.5066 - val_accuracy: 0.7323
# 51/51 [==============================] - 0s 3ms/step

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       852
#            1       1.00      0.44      0.61       773
#
#     accuracy                           0.73      1625
#    macro avg       0.83      0.72      0.70      1625
# weighted avg       0.82      0.73      0.71      1625
#
# [[852   0]
#  [435 338]]
