# %%
from sklearn.datasets import load_wine
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 와인 데이터를 로드한다.
wine_data = load_wine()
df_data=pd.DataFrame(wine_data.data, columns= wine_data.feature_names)
df_target=pd.DataFrame(wine_data.target, columns=["kind"])
totall_data= pd.concat([df_data,df_target], axis=1)
sns.countplot(data=totall_data, x="kind")
plt.xlabel("kind")
plt.ylabel("Count")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
totall_data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  kind
# 0                            3.92   1065.0     0
# 1                            3.40   1050.0     0
# 2                            3.17   1185.0     0
# 3                            3.45   1480.0     0
# 4                            2.93    735.0     0
# ..                            ...      ...   ...
# 173                          1.74    740.0     2
# 174                          1.56    750.0     2
# 175                          1.56    835.0     2
# 176                          1.62    840.0     2
# 177                          1.60    560.0     2
#
# [178 rows x 14 columns]

# %%
totall_data.plot(kind='scatter',
        x= 'hue',
        y= 'kind',
        title='Test')
plt.show()

# %%
totall_data.plot(kind='scatter',
        x= 'color_intensity',
        y= 'kind',
        title='Test')
plt.show()

# %%
plt.scatter(totall_data['hue'],df_data['color_intensity'])
plt.xlabel('hue')
plt.ylabel('color_intensity')

plt.show()

# %%
sns.pairplot(totall_data,
             vars=['color_intensity','hue'],
            hue ='kind')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(x="color_intensity", data=totall_data, palette="Set3")
plt.title("range")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(df_data,
                                                    df_target,
                                                    test_size=0.25,
                                                    random_state=0)

# %%
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)

pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# --- SVM Classifier ---
# 0.8222222222222222
# [[15  0  1]
#  [ 0 17  4]
#  [ 0  3  5]]
# C:\Users\Cold min\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Build a logistic regression classifier and predict

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.9333333333333333
# [[14  2  0]
#  [ 0 20  1]
#  [ 0  0  8]]
# C:\Users\Cold min\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Cold min\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf_nn = MLPClassifier(random_state=0)
clf_nn.fit(X_train, y_train)

pred_nn = clf_nn.predict(X_test)

print ("\n--- Neural Network Classifier ---")
print (accuracy_score(y_test, pred_nn))
print (confusion_matrix(y_test, pred_nn))
# Out:
# C:\Users\Cold min\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# --- Neural Network Classifier ---
# 0.9555555555555556
# [[15  1  0]
#  [ 0 20  1]
#  [ 0  0  8]]
# C:\Users\Cold min\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Build a decision tree classifier and predict

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.9333333333333333
# [[14  2  0]
#  [ 0 20  1]
#  [ 0  0  8]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

print ("\n--- Radom Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,pred))
print (confusion_matrix(y_test, pred))
# Out:
# --- Radom Forest ---
# 0.9777777777777777
# [[16  0  0]
#  [ 0 20  1]
#  [ 0  0  8]]

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

k_range = range(1, 201)
find_accuracy = []

for k in k_range:
  find_model = KNeighborsClassifier(n_neighbors = k)
  find_model.fit(X_train, y_train.values.ravel())

  find_accuracy.append(find_model.score(X_test, y_test))
  
plt.plot(k_range, find_accuracy, label="training accuracy")
plt.xlabel("k value")
plt.ylabel("Accuracy")
plt.title("Find Breast Cancer Classifier Accuracy")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21400\347311547.py in <module>
#       9   find_model.fit(X_train, y_train.values.ravel())
#      10
# ---> 11   find_accuracy.append(find_model.score(X_test, y_test))
#      12
#      13 plt.plot(k_range, find_accuracy, label="training accuracy")
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     649         from .metrics import accuracy_score
#     650
# --> 651         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     652
#     653     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     212             Class labels for each data sample.
#     213         """
# --> 214         neigh_dist, neigh_ind = self.kneighbors(X)
#     215         classes_ = self.classes_
#     216         _y = self._y
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     725         n_samples_fit = self.n_samples_fit_
#     726         if n_neighbors > n_samples_fit:
# --> 727             raise ValueError(
#     728                 "Expected n_neighbors <= n_samples, "
#     729                 " but n_samples = %d, n_neighbors = %d" % (n_samples_fit, n_neighbors)
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 133, n_neighbors = 134

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

k_range = range(1, 101)
find_accuracy = []

for k in k_range:
  find_model = KNeighborsClassifier(n_neighbors = k)
  find_model.fit(X_train, y_train.values.ravel())

  find_accuracy.append(find_model.score(X_test, y_test))
  
plt.plot(k_range, find_accuracy, label="training accuracy")
plt.xlabel("k value")
plt.ylabel("Accuracy")
plt.title("Find Breast Cancer Classifier Accuracy")
plt.show()
